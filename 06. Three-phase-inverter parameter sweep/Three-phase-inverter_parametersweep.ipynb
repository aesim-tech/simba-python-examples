# %%
import numpy as np
import pandas as pd
import os
import time as t
from scipy import signal
from aesim.simba import Design, ProjectRepository
from bokeh.plotting import figure
from bokeh.io import show, output_notebook

# %% [markdown]
# # Three-phase-inverter: sweep of modulation depth $m$ depending on dc bus voltage $E$
#
# ![Three-phase-inverter](fig/three-phase-inverter.png)

# %% [markdown]
# #### Different dc bus voltages $E$ are considered
# #### Modulation depth $m$ is recomputed to get the same line-line voltage $U$ according to the relation: $$ m = \frac{2 U \sqrt{2}}{E \sqrt{3}} $$

# %%
line_line_voltage = 300
fmod = 50
dc_bus_voltages = [800, 700, 600]
modulation_depths = 2 * line_line_voltage * np.sqrt(2) / dc_bus_voltages / np.sqrt(3)

# %%
project = ProjectRepository(os.path.join(os.getcwd(),"Three-phase-inverter.jsimba"))
mycvs = project.GetDesignByName('three-phase-inverter')
vdc1 = mycvs.Circuit.GetDeviceByName('DC1')
vdc2 = mycvs.Circuit.GetDeviceByName('DC2')
pwms = [mycvs.Circuit.GetDeviceByName('SIN'+k) for k in ['1', '2', '3']]

res_u12_time = []
res_u12 = []
res_iL_time = []
res_iL = []

tic = t.process_time()
for dc_bus_voltage, modulation_depth in zip(dc_bus_voltages, modulation_depths):
    vdc1.Voltage = dc_bus_voltage / 2
    vdc2.Voltage = dc_bus_voltage / 2
    for pwm in pwms:
        pwm.Amplitude = float(modulation_depth)
        pwm.Frequency = float(fmod)
    job = mycvs.TransientAnalysis.NewJob()
    status = job.Run()
    if str(status) != "OK": 
        raise Exception(job.Summary())
    u12 = job.GetSignalByName('U12 - Voltage')
    res_u12_time.append(u12.TimePoints)
    res_u12.append(u12.DataPoints) 
    
    il = job.GetSignalByName('L1 - Current')
    res_iL_time.append(il.TimePoints)
    res_iL.append(il.DataPoints) 

toc = t.process_time()
print('Elapsed time to simulate = ', toc - tic)
# Out:
# Elapsed time to simulate =  0.375

# %%
# plot
TOOLTIPS = [
    ("index", "$index"),
    ("(t, val)", "($x, $y)"),
    ]

# figure 1
p1 = figure(width = 800, height = 300, 
           title = 'Line-line voltage',
           x_axis_label = 'time (s)', y_axis_label = 'Voltage (V)',
           active_drag='box_zoom',
           tooltips = TOOLTIPS)
# figure 2
p2 = figure(width = 800, height = 300, 
           title = 'Line current',
           x_axis_label = 'time (s)', y_axis_label = 'Current (A)',
           active_drag='box_zoom',
           tooltips = TOOLTIPS)

green_color = 50
for u12_time, u12, iL_time, iL in zip(res_u12_time, res_u12, res_iL_time, res_iL):
    p1.line(u12_time, u12, color=(0, green_color, 0))
    p2.line(iL_time, iL, color=(0, green_color, 0))
    green_color += 100

output_notebook()
show(p1)
show(p2)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="f64eef17-8f6b-43b9-b847-b747c33174b1">Loading BokehJS ...</span>
#     </div>
#   <div id="c52e7299-bca0-4be3-bf51-ddc9e1dd6924" data-root-id="p1410" style="display: contents;"></div>
#   <div id="b31780eb-8098-4e2e-8219-68fcd8853a2d" data-root-id="p1446" style="display: contents;"></div>

# %%
# Prepare figure
TOOLTIPS = [
    ("index", "$index"),
    ("(freq, val)", "($x, $y)"),
    ]
p1 = figure(width = 800, height = 300, 
           title = 'Frequency Spectrum',
           x_axis_label = 'frequency (kHz)', y_axis_label = 'Voltage (V)',
           active_drag='box_zoom',
           tooltips = TOOLTIPS)
green_color = 50
width = 0.02

# Prepare resampling
N = 10000
time_resamp = np.linspace(0, 2 / fmod, 2 * N, endpoint=False)

for time, u12 in zip(res_u12_time, res_u12):
    # resampling for fft
    u12_resamp = np.interp(time_resamp, time, u12)
    fstep = 50    # consider only N points of the 2N point resampled vector
    time_resamp_window = time_resamp[N:]
    u12_resamp_window = u12_resamp[N:]
    
    # do fft
    freq = np.fft.fftfreq(N) * fstep * N
    positivefreq = freq[freq >= 0]
    freqval = np.abs(np.fft.fft(u12_resamp_window)) / N
    freqval[1:] = freqval[1:] * 2
    freqval = freqval[freq >= 0]

    # Get only 300 harmonics
    max_index = 300
    positivefreq = positivefreq[:300]
    freqval = freqval[:300]
    p1.vbar(x=(positivefreq/1e3), width=width, bottom=0, top=freqval, color=(0, green_color, 0))
    green_color += 100
    width *= 0.5

show(p1)
# Out:
#   <div id="fa5d48f1-d7bf-44ae-92a4-b8b15a82bf91" data-root-id="p1540" style="display: contents;"></div>
